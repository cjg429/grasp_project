# %%
import numpy as np
import os
import re
import pickle
import json
import tensorflow as tf
import random
from gqcnn_network import GQCNN
import matplotlib.pyplot as plt
np.set_printoptions(precision=4, edgeitems=6, linewidth=100, suppress=True)
os.environ["CUDA_VISIBLE_DEVICES"]="" # disable GPU

# %%
#raw_data = np.load("/home/cjg429/Desktop/gqcnn-master/data/training/example_pj/tensors/tf_depth_ims_00000.npz")
raw_data = np.load("/home/cjg429/Desktop/gqcnn-master/data/training/data/training/mini-dexnet_fc_pj_10_02_18/grasps/tensors/tf_depth_ims_01557.npz")

# %%
img = raw_data['arr_0']
print(img.shape)
# Out:
# (35, 96, 96, 1)

# %%
for i in range(img.shape[0]):
    plt.imshow(img[i, :, :, 0], cmap='gray')
    plt.show()

# %%
DATA_DIR = "/home/cjg429/Desktop/gqcnn-master/data/training/data/training/mini-dexnet_fc_pj_10_02_18/grasps/tensors/tf_depth_ims_"
for i in range(10, 100):
    raw_data = np.load(DATA_DIR + "000" + str(i) + ".npz")
    img = raw_data['arr_0']
    plt.imshow(img[0, :, :, 0], cmap='gray')#, vmin=0, vmax=1)
    plt.show()

# %%
DATA_DIR = "/home/cjg429/Desktop/gqcnn-master/data/training/data/training/mini-dexnet_fc_pj_10_02_18/grasps/splits/image_wise_1/train_indices.npz"
raw_data = np.load(DATA_DIR)
data = raw_data['arr_0']
print(data)
# Out:
# [     0      2      3      4      5      7 ..., 155728 155729 155730 155731 155732 155734]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
            ax1.imshow(occmap, cmap='gray', vmin=0, vmax=1)
            ax2.imshow(reconstruct.reshape(64, 64), cmap='gray', vmin=0, vmax=1)
            plt.show()
# Out:
#   File "<ipython-input-7-6c4971618965>", line 3
#     ax1.imshow(occmap, cmap='gray', vmin=0, vmax=1)
#     ^
# IndentationError: unexpected indent
